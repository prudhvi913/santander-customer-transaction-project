# %%
# importing all the necessary data operation libraries.
import os
os.chdir("D:/R and PYTHON files/data set/project 2")
os.getcwd()
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# loading the train data
train_data=pd.read_csv("train.csv",sep=',')

# %%
# loading the test data
test_data=pd.read_csv("test.csv",sep=',')

# %%
# exploratory data analysis
train_data.shape
# Out:
# (200000, 202)

# %%
test_data.shape
# Out:
# (200000, 201)

# %%
# train_data.head()
train_data.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
# test_data.head()
test_data.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# ...

# %%
train_data['target'].value_counts().plot.bar();

# %% [markdown]
# %matplotlib inline
# plt.boxplot(test_data['var_190'])

# %%
train_data['target'].value_counts()# this seems to be a class imbalance data set.
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
sns.violinplot(data=train_data,x="target",y="var_1").get_figure().savefig("violin1.png")

# %%
sns.violinplot(data=train_data,x="target",y="var_110").get_figure().savefig("violin100.png")

# %%
numerical_cols=["ID_code","target"]
numeric_features=train_data.drop(numerical_cols,axis=1)
#y=train_data["target"]
numeric_features.head()
# Out:
#      var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7   var_8  \
# 0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266 -4.9200
# 1  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208  16.5338  3.1468
# 2   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155 -4.9193
# 3  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428  14.9250 -5.8609
# 4   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405  19.2514  6.2654
#
#     var_9  ...  var_190  var_191  var_192  var_193  var_194  var_195  var_196  \
# 0  5.7470  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978   7.8784
# 1  8.0851  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339   8.1267
# 2  5.9525  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417  -6.5213
# 3  8.2450  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706  -2.9275
# 4  7.6784  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121   3.9267
#
# ...

# %%
df_corr=numeric_features
f,ax=plt.subplots(figsize=(7,5))
corr=df_corr.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax).get_figure().savefig('heatmap.png')

# %%
train_data.isnull().sum().sum(),test_data.isnull().sum().sum()
numeric_features.shape
# Out:
# (200000, 200)

# %%
# saving the fig in directory

#plt.hist(train_data['var_0'])
#plt.savefig('hist_v0.png')

plt.hist(train_data['var_100'])
plt.savefig('hist_v100.png')

#plt.hist(train_data['var_10'])
#plt.savefig('hist_v10.png')

#plt.hist(train_data['var_120'])
#plt.savefig('hist_v120.png')

# %%
# checking the distributon of the features.
for i,col in enumerate (numeric_features):
    plt.figure(figsize=(10,30))
    plt.subplot(50,4,i+1)
    plt.hist(train_data[col])
    plt.title(col)
# Out:
# C:\Users\ELCOT\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# checking the distribution of target vaibale for each feature.
for i,col in enumerate (numeric_features):
    plt.figure(figsize=(20,40))
    plt.subplot(50,4,i+1)
    plt.hist(train_data[train_data["target"]==0][col],alpha=0.5,label='0',color='green')
    plt.hist(train_data[train_data["target"]==1][col],alpha=0.5,label='1',color='yellow')
    plt.title(col)
# Out:
# C:\Users\ELCOT\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
# mean frequency 
plt.figure(figsize=(20,8))
numeric_features.mean().plot('hist').get_figure().savefig('mean_freq.png')
plt.title('mean frequency');

# %%
#median frequency
plt.figure(figsize=(20,8))
numeric_features.median().plot('hist').get_figure().savefig('mean_freq.png')
plt.title('median frequency');

# %%
# standard deviation freq.
plt.figure(figsize=(20,8))
numeric_features.std().plot('hist').get_figure().savefig('mean_freq.png')
plt.title('standard deviation frequency');

# %%
# checking skewness
plt.figure(figsize=(20,8))
numeric_features.skew().plot('hist').get_figure().savefig('mean_freq.png')
plt.title('skew frequency');

# %%
# kurtosis
plt.figure(figsize=(20,8))
numeric_features.kurt().plot('hist').get_figure().savefig('mean_freq.png')
plt.title('kurtosis frequency');

# %%
# preparing the data for logistic regression model model
columns=["ID_code","target"]
x=train_data.drop(columns,axis=1)

# %%
# importing all the necessary library for model
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import statsmodels.api as sm

# %%
# logistic regression
logistic_model = sm.Logit(train_data['target'],x).fit()
logistic_model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.231171
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:               200000
# Model:                          Logit   Df Residuals:                   199800
# Method:                           MLE   Df Model:                          199
# Date:                Fri, 11 Oct 2019   Pseudo R-squ.:                  0.2912
# Time:                        00:47:21   Log-Likelihood:                -46234.
# converged:                       True   LL-Null:                       -65232.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
col=["ID_code"]
xtest=test_data.drop(col,axis=1)

# %%
prediction_logistic=logistic_model.predict(xtest)

# %%
prediction_logistic.describe()
# Out:
# count    200000.000000
# mean          0.095172
# std           0.140332
# min           0.000027
# 25%           0.014268
# 50%           0.040063
# 75%           0.110583
# max           0.995772
# dtype: float64

# %%
# preparing the data for decision tree and randon forest
y=train_data["target"]

# %%
# decision tree classifier
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state=1)
tree_model = tree.DecisionTreeClassifier(criterion='entropy').fit(train_x,train_y)

# %%
print(tree_model)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions_tree=tree_model.predict(xtest)
predictions_tree
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# random forest classifier
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state=1)
rfc_model =RandomForestClassifier(random_state=0).fit(train_x, train_y)
# Out:
# C:\Users\ELCOT\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
predict_rfc=rfc_model.predict(xtest)
predict_rfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# variable importance
import eli5
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(rfc_model, random_state=1).fit(val_x, val_y)

# %%
eli5.show_weights(perm, feature_names = val_x.columns.tolist(), top=200)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 var_110
#             </td>
# ...

# %%
# What can be inferred from the above?
# As you move down the graph, the importance of the feature decreases.
# The features that are shown in green indicate that they have a positive impact on our prediction
# The features that are shown in white indicate that they have no effect on our prediction
# The features shown in red indicate that they have a negative impact on our prediction
# The most important feature was Var_110.
